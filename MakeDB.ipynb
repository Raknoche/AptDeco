# %%
import pandas as pd
from sqlalchemy import create_engine
df = pd.read_csv('/Users/richardknoche/Desktop/Order Items.csv',encoding='latin-1')
# Out:
# /Users/richardknoche/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (9,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    id  order_id  product_id  \
# 0   1        57      1044.0
# 1   2        58         NaN
# 2   3        59         NaN
# 3   4        60      1263.0
# 4   6        62      1064.0
#
#                                              options  is_delivered  \
# 0  a:2:{s:11:"buyer_dates";a:3:{i:0;s:21:"2013-04...             1
# 1  a:1:{s:11:"buyer_dates";a:1:{i:0;s:21:"2013-04...             1
# 2  a:2:{s:11:"buyer_dates";a:3:{i:0;s:21:"2013-04...             1
# 3                                                NaN             1
# 4                                                NaN             1
#
#    is_received  is_available    status  qty product_title  \
# 0            1           0.0  complete    1           NaN
# 1            1           0.0  complete    1           NaN
# 2            1           0.0  complete    1           NaN
# 3            1           0.0  complete    1           NaN
# 4            1           0.0  complete    1           NaN
#
# ...

# %%
engine = create_engine("mysql+pymysql://raknoche:localpswd@localhost/AptDeco")
df.to_sql('OrderItems', engine, if_exists='replace', index=False)
